# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
from tqdm import tqdm # Added for progress bar

CSV_PATH = 'data/nacti_metadata.csv'
DATA_DIR = 'data/'
PROCESS_ALL = True # Assuming you now want to process the full dataset
TARGET_SIZE = (448, 448) # Increased to preserve features from HD images

# 1. Faster transformations using PyTorch's native C++ backend via torchvision
train_transforms = transforms.Compose([
    transforms.Resize(TARGET_SIZE),
    transforms.RandomHorizontalFlip(), # Basic augmentation for training
    transforms.ToTensor(), # Converts to [0, 1] and structures as (C, H, W)
    transforms.Normalize(mean=[0.485, 0.456, 0.406], # ImageNet standards
                         std=[0.229, 0.224, 0.225])
])

def load_labels(csv_path):
    df = pd.read_csv(csv_path, low_memory=False)
    return dict(zip(df['filename'], df['common_name']))

# 2. Refactored into a lazy-loading PyTorch Dataset
class StreamingCameraTrapDataset(Dataset):
    """Stores only file paths in RAM. Streams and processes images on-the-fly."""
    def __init__(self, data_dir, csv_path, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        label_dict = load_labels(csv_path)
        
        self.filepaths = []
        self.labels = []
        
        # Scan directories and build paths (fast, uses almost no RAM)
        print("Scanning directories for images...")
        for i in range(0, 4):
            part_folder = f"part{i}"
            part_path = os.path.join(self.data_dir, part_folder)
            
            if not os.path.exists(part_path):
                continue
                
            for root, _, files in os.walk(part_path):
                for file in files:
                    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                        full_path = os.path.join(root, file)
                        rel_path = os.path.relpath(full_path, self.data_dir).replace('\\', '/')
                        
                        label = label_dict.get(rel_path, "unlabeled")
                        self.filepaths.append(full_path)
                        self.labels.append(label)

        # Encode string labels to integers
        self.unique_labels = sorted(list(set(self.labels)))
        self.label_to_idx = {label: idx for idx, label in enumerate(self.unique_labels)}
        self.encoded_labels = [self.label_to_idx[lbl] for lbl in self.labels]
        
        print(f"Found {len(self.filepaths)} images across {len(self.unique_labels)} classes.")

    def __len__(self):
        return len(self.filepaths)

    def __getitem__(self, idx):
        # Image is only opened when requested by the DataLoader
        img_path = self.filepaths[idx]
        try:
            with Image.open(img_path) as img:
                img = img.convert('RGB')
                if self.transform:
                    img = self.transform(img)
        except Exception as e:
            # Fallback to a black image tensor if file is corrupt
            img = torch.zeros((3, TARGET_SIZE[0], TARGET_SIZE[1]))
            
        label = self.encoded_labels[idx]
        return img, torch.tensor(label, dtype=torch.long)

class NACTI_ResNet50(nn.Module):
    def __init__(self, num_classes):
        super(NACTI_ResNet50, self).__init__()
        self.backbone = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
        
        for param in list(self.backbone.parameters())[:-30]:
            param.requires_grad = False
            
        num_ftrs = self.backbone.fc.in_features
        self.backbone.fc = nn.Sequential(
            nn.Dropout(0.4),
            nn.Linear(num_ftrs, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.backbone(x)

if __name__ == "__main__":
    # Initialize streaming dataset
    dataset = StreamingCameraTrapDataset(DATA_DIR, CSV_PATH, transform=train_transforms)
    
    if len(dataset) == 0:
        print("No images found. Check your DATA_DIR path.")
        exit()

    num_classes = len(dataset.unique_labels)
    
    # DataLoader heavily optimized for HPC runtime:
    # num_workers > 0 enables multiprocessing for data loading
    # pin_memory=True speeds up the transfer of tensors from host CPU to GPU
    dataloader = DataLoader(
        dataset, 
        batch_size=64, 
        shuffle=True, 
        num_workers=8,  # Adjust based on HPC CPU cores
        pin_memory=True, 
        prefetch_factor=2
    )
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training on device: {device}")
    
    model = NACTI_ResNet50(num_classes=num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)
    
    # Initialize Gradient Scaler for Automatic Mixed Precision (AMP)
    scaler = torch.amp.GradScaler('cuda') 
    
    epochs = 5
    model.train()
    
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        
        # Wrap the dataloader in tqdm for the progress bar
        pbar = tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}", unit="batch")
        
        for inputs, labels in pbar:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True) # Slightly faster than standard zero_grad()
            
            # Cast forward pass to 16-bit precision
            with torch.amp.autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
            
            # Scale the loss and call backward to prevent gradient underflow
            scaler.scale(loss).backward()
            
            # Step optimizer and update scale
            scaler.step(optimizer)
            scaler.update()
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            # Update progress bar with live metrics
            current_loss = running_loss / (total / inputs.size(0))
            current_acc = 100 * correct / total
            pbar.set_postfix({"Loss": f"{current_loss:.4f}", "Acc": f"{current_acc:.2f}%"})
            
        print(f"\\nEpoch {epoch+1} Completed | Final Loss: {current_loss:.4f} | Final Acc: {current_acc:.2f}%\\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 107
#     103         return self.backbone(x)
#     105 if __name__ == "__main__":
#     106     # Initialize streaming dataset
# --> 107     dataset = StreamingCameraTrapDataset(DATA_DIR, CSV_PATH, transform=train_transforms)
#     109     if len(dataset) == 0:
#     110         print("No images found. Check your DATA_DIR path.")
#
# Cell In[1], line 36, in StreamingCameraTrapDataset.__init__(self, data_dir, csv_path, transform)
#      34 self.data_dir = data_dir
#      35 self.transform = transform
# ---> 36 label_dict = load_labels(csv_path)
#      38 self.filepaths = []
#      39 self.labels = []
#
# Cell In[1], line 27, in load_labels(csv_path)
#      26 def load_labels(csv_path):
# ---> 27     df = pd.read_csv(csv_path, low_memory=False)
#      28     return dict(zip(df['filename'], df['common_name']))
#
# ...
